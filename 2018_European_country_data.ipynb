# %%
import pandas as pd
import numpy as np

# %% [markdown]
# creat a dataframe of European countries's prevalence estimates of intimate partner violence

# %%
df_europa = pd.DataFrame({'Survey_year': ['01/01/2018', '01/01/2018', '01/01/2018', '01/01/2018','01/01/2018',
                                   '01/01/2018', '01/01/2018', '01/01/2018', '01/01/2018','01/01/2018',
                                   '01/01/2018', '01/01/2018', '01/01/2018', '01/01/2018','01/01/2018','01/01/2018',
                                   '01/01/2018', '01/01/2018', '01/01/2018', '01/01/2018','01/01/2018',
                                   '01/01/2018', '01/01/2018', '01/01/2018', '01/01/2018','01/01/2018',
                                   '01/01/2018', '01/01/2018', '01/01/2018', '01/01/2018','01/01/2018',
                                   '01/01/2018', '01/01/2018', '01/01/2018', '01/01/2018','01/01/2018',
                                   '01/01/2018', '01/01/2018', '01/01/2018', '01/01/2018','01/01/2018',
                                   '01/01/2018', '01/01/2018', '01/01/2018', '01/01/2018','01/01/2018'], 
                   
                   'Country': ['Albania', 'Armenia', 'Azerbaijan', 'Belarus', 'Bosnia and Herzegovina', 
                               'Georgia', 'Kazakhstan', 'Kosovo', 'Kyrgyzstan', 'Montenegro', 
                               'North Macedonia', 'Republic of Moldova', 'Serbia', 'Tajikistan', 'Turkey', 'Ukraine',
                               'Austria', 'Belgium', 'Bulgaria', 'Croatia','Cyprus',
                               'Czechia','Denmark','Estonia','Finland','France',
                               'Greece','Hungary','Iceland','Ireland', 'Italy',
                               'Latvia','Lithuania','Luxembourg','Malta','Netherlands',
                               'Norway','Poland','Portugal','Romania','Slovakia',
                               'Slovenia','Spain','Sweden','Switzerland','United Kingdom of Great Britain and Northern Ireland'], 
                   
                   'Value':[13, 10, 14, 21, 12, 
                            10, 16, 13, 23, 16, 
                            13, 27, 17, 24, 32, 18,
                            15, 22, 19, 13, 16, 
                            22, 23, 21, 23, 22,
                            18, 19, 21, 16, 16,
                            25, 22, 20, 17, 21,
                            20, 13, 18, 18, 18,
                            18, 15, 21, 12, 24
                           ]})

df_europa
# Out:
#    Survey_year                                            Country  Value
# 0   01/01/2018                                            Albania     13
# 1   01/01/2018                                            Armenia     10
# 2   01/01/2018                                         Azerbaijan     14
# 3   01/01/2018                                            Belarus     21
# 4   01/01/2018                             Bosnia and Herzegovina     12
# 5   01/01/2018                                            Georgia     10
# 6   01/01/2018                                         Kazakhstan     16
# 7   01/01/2018                                             Kosovo     13
# 8   01/01/2018                                         Kyrgyzstan     23
# 9   01/01/2018                                         Montenegro     16
# 10  01/01/2018                                    North Macedonia     13
# 11  01/01/2018                                Republic of Moldova     27
# ...

# %%
df_europa.to_csv('cleaned_data_2.csv', index = False, header = True)
